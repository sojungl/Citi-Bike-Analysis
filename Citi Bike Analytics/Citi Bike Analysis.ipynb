# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')

# %%
df1 = pd.read_csv("JC-201706-citibike-tripdata.csv")

# %%
df1.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           499  2017-06-01 00:01:39  2017-06-01 00:09:59              3195
# 1           507  2017-06-01 00:06:39  2017-06-01 00:15:07              3211
# 2           768  2017-06-01 00:44:43  2017-06-01 00:57:31              3195
# 3           101  2017-06-01 01:12:55  2017-06-01 01:14:36              3185
# 4           265  2017-06-01 01:14:00  2017-06-01 01:18:25              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# ...

# %%
df1.count()
# Out:
# tripduration               32060
# starttime                  32060
# stoptime                   32060
# start station id           32060
# start station name         32060
# start station latitude     32060
# start station longitude    32060
# end station id             32060
# end station name           32060
# end station latitude       32060
# end station longitude      32060
# bikeid                     32060
# usertype                   32060
# birth year                 29534
# gender                     32060
# dtype: int64

# %%
df2 = pd.read_csv("JC-201707-citibike-tripdata.csv")

# %%
df2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           340  2017-07-01 00:00:08  2017-07-01 00:05:48              3186
# 1           439  2017-07-01 00:02:35  2017-07-01 00:09:55              3183
# 2           186  2017-07-01 00:04:33  2017-07-01 00:07:40              3186
# 3           442  2017-07-01 00:05:53  2017-07-01 00:13:15              3195
# 4           170  2017-07-01 00:07:54  2017-07-01 00:10:45              3187
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1     Exchange Place               40.716247               -74.033459
# 2      Grove St PATH               40.719586               -74.043117
# 3            Sip Ave               40.730743               -74.063784
# 4          Warren St               40.721124               -74.038051
#
#    end station id end station name  end station latitude  \
# ...

# %%
df2.count()
# Out:
# tripduration               33573
# starttime                  33573
# stoptime                   33573
# start station id           33573
# start station name         33573
# start station latitude     33573
# start station longitude    33573
# end station id             33573
# end station name           33573
# end station latitude       33573
# end station longitude      33573
# bikeid                     33573
# usertype                   33573
# birth year                 30613
# gender                     33573
# dtype: int64

# %%
df3 = pd.read_csv("JC-201708 citibike-tripdata.csv")

# %%
df3.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1314  2017-08-01 00:03:05  2017-08-01 00:24:59              3187
# 1           221  2017-08-01 00:06:25  2017-08-01 00:10:06              3213
# 2           185  2017-08-01 00:42:28  2017-08-01 00:45:33              3211
# 3            72  2017-08-01 00:45:06  2017-08-01 00:46:18              3269
# 4           499  2017-08-01 01:12:10  2017-08-01 01:20:30              3185
#
#   start station name  start station latitude  start station longitude  \
# 0          Warren St               40.721124               -74.038051
# 1     Van Vorst Park               40.718489               -74.047727
# 2         Newark Ave               40.721525               -74.046305
# 3    Brunswick & 6th               40.726012               -74.050389
# 4          City Hall               40.717733               -74.043845
#
#    end station id end station name  end station latitude  \
# ...

# %%
df3.count()
# Out:
# tripduration               35472
# starttime                  35472
# stoptime                   35472
# start station id           35472
# start station name         35472
# start station latitude     35472
# start station longitude    35472
# end station id             35472
# end station name           35472
# end station latitude       35472
# end station longitude      35472
# bikeid                     35472
# usertype                   35472
# birth year                 32803
# gender                     35472
# dtype: int64

# %%
df4 = pd.read_csv("JC-201806-citibike-tripdata.csv")

# %%
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
df4.count()
# Out:
# tripduration               40937
# starttime                  40937
# stoptime                   40937
# start station id           40937
# start station name         40937
# start station latitude     40937
# start station longitude    40937
# end station id             40937
# end station name           40937
# end station latitude       40937
# end station longitude      40937
# bikeid                     40937
# usertype                   40937
# birth year                 40937
# gender                     40937
# dtype: int64

# %%
df5 = pd.read_csv("JC-201807-citibike-tripdata.csv")

# %%
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
df5.count()
# Out:
# tripduration               42268
# starttime                  42268
# stoptime                   42268
# start station id           42268
# start station name         42268
# start station latitude     42268
# start station longitude    42268
# end station id             42268
# end station name           42268
# end station latitude       42268
# end station longitude      42268
# bikeid                     42268
# usertype                   42268
# birth year                 42268
# gender                     42268
# dtype: int64

# %%
df6 = pd.read_csv("JC-201808-citibike-tripdata.csv")

# %%
df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
df6.count()
# Out:
# tripduration               44432
# starttime                  44432
# stoptime                   44432
# start station id           44432
# start station name         44432
# start station latitude     44432
# start station longitude    44432
# end station id             44432
# end station name           44432
# end station latitude       44432
# end station longitude      44432
# bikeid                     44432
# usertype                   44432
# birth year                 44432
# gender                     44432
# dtype: int64

# %% [markdown]
# # Merge all 6 files

# %%
df12 = df1.append(df2)

# %%
df12.tail()
# Out:
#        tripduration            starttime             stoptime  \
# 33568           466  2017-07-31 23:25:04  2017-07-31 23:32:51
# 33569           759  2017-07-31 23:27:33  2017-07-31 23:40:12
# 33570           320  2017-07-31 23:35:52  2017-07-31 23:41:12
# 33571          1100  2017-07-31 23:46:15  2017-08-01 00:04:36
# 33572           310  2017-07-31 23:47:14  2017-07-31 23:52:24
#
#        start station id start station name  start station latitude  \
# 33568              3195            Sip Ave               40.730743
# 33569              3195            Sip Ave               40.730743
# 33570              3207        Oakland Ave               40.737604
# 33571              3280        Astor Place               40.719282
# 33572              3210     Pershing Field               40.742677
#
#        start station longitude  end station id end station name  \
# 33568               -74.063784            3191         Union St
# ...

# %%
df12.count()
# Out:
# tripduration               65633
# starttime                  65633
# stoptime                   65633
# start station id           65633
# start station name         65633
# start station latitude     65633
# start station longitude    65633
# end station id             65633
# end station name           65633
# end station latitude       65633
# end station longitude      65633
# bikeid                     65633
# usertype                   65633
# birth year                 60147
# gender                     65633
# dtype: int64

# %%
df123 = df12.append(df3) 
df123.tail()
# Out:
#        tripduration            starttime             stoptime  \
# 35467           416  2017-08-31 23:40:33  2017-08-31 23:47:30
# 35468           165  2017-08-31 23:42:20  2017-08-31 23:45:06
# 35469           326  2017-08-31 23:42:34  2017-08-31 23:48:00
# 35470           345  2017-08-31 23:42:37  2017-08-31 23:48:23
# 35471           332  2017-08-31 23:42:54  2017-08-31 23:48:27
#
#        start station id start station name  start station latitude  \
# 35467              3203      Hamilton Park               40.727596
# 35468              3186      Grove St PATH               40.719586
# 35469              3199       Newport Pkwy               40.728745
# 35470              3209       Brunswick St               40.724176
# 35471              3209       Brunswick St               40.724176
#
#        start station longitude  end station id end station name  \
# 35467               -74.044247            3186    Grove St PATH
# ...

# %%
df123.count()
# Out:
# tripduration               101105
# starttime                  101105
# stoptime                   101105
# start station id           101105
# start station name         101105
# start station latitude     101105
# start station longitude    101105
# end station id             101105
# end station name           101105
# end station latitude       101105
# end station longitude      101105
# bikeid                     101105
# usertype                   101105
# birth year                  92950
# gender                     101105
# dtype: int64

# %%
df1234 = df123.append(df4) 
df1234.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 40932          1227  2018-06-30 20:46:55.7500  2018-06-30 21:07:22.9730
# 40933          1219  2018-06-30 20:47:02.7610  2018-06-30 21:07:22.1720
# 40934          1227  2018-06-30 20:47:03.1250  2018-06-30 21:07:30.3560
# 40935           252  2018-06-30 21:13:35.6890  2018-06-30 21:17:48.5690
# 40936           652  2018-06-30 22:03:44.8150  2018-06-30 22:14:37.5310
#
#        start station id start station name  start station latitude  \
# 40932              3681           Grand St               40.715178
# 40933              3681           Grand St               40.715178
# 40934              3681           Grand St               40.715178
# 40935              3681           Grand St               40.715178
# 40936              3681           Grand St               40.715178
#
#        start station longitude  end station id end station name  \
# ...

# %%
df1234.count()
# Out:
# tripduration               142042
# starttime                  142042
# stoptime                   142042
# start station id           142042
# start station name         142042
# start station latitude     142042
# start station longitude    142042
# end station id             142042
# end station name           142042
# end station latitude       142042
# end station longitude      142042
# bikeid                     142042
# usertype                   142042
# birth year                 133887
# gender                     142042
# dtype: int64

# %%
df12345 = df1234.append(df5) 
df12345.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 42263           993  2018-07-31 08:51:08.1240  2018-07-31 09:07:41.5700
# 42264           311  2018-07-31 10:15:37.0040  2018-07-31 10:20:48.0740
# 42265           795  2018-07-31 15:45:01.4740  2018-07-31 15:58:16.6240
# 42266           918  2018-07-31 16:06:19.5890  2018-07-31 16:21:37.9990
# 42267          1956  2018-07-31 18:06:02.2850  2018-07-31 18:38:38.9730
#
#        start station id start station name  start station latitude  \
# 42263              3694     Jackson Square                40.71113
# 42264              3694     Jackson Square                40.71113
# 42265              3694     Jackson Square                40.71113
# 42266              3694     Jackson Square                40.71113
# 42267              3694     Jackson Square                40.71113
#
#        start station longitude  end station id       end station name  \
# ...

# %%
df12345.count()
# Out:
# tripduration               184310
# starttime                  184310
# stoptime                   184310
# start station id           184310
# start station name         184310
# start station latitude     184310
# start station longitude    184310
# end station id             184310
# end station name           184310
# end station latitude       184310
# end station longitude      184310
# bikeid                     184310
# usertype                   184310
# birth year                 176155
# gender                     184310
# dtype: int64

# %%
dfAll = df12345.append(df6) 
dfAll.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 44427           462  2018-08-25 16:17:05.8840  2018-08-25 16:24:48.5890
# 44428           636  2018-08-28 12:31:22.4380  2018-08-28 12:41:59.2110
# 44429           954  2018-08-30 08:08:18.9250  2018-08-30 08:24:13.7900
# 44430           920  2018-08-31 08:08:54.2450  2018-08-31 08:24:14.8890
# 44431          1017  2018-08-31 12:57:23.8390  2018-08-31 13:14:20.9290
#
#        start station id start station name  start station latitude  \
# 44427              3694     Jackson Square                40.71113
# 44428              3694     Jackson Square                40.71113
# 44429              3694     Jackson Square                40.71113
# 44430              3694     Jackson Square                40.71113
# 44431              3694     Jackson Square                40.71113
#
#        start station longitude  end station id end station name  \
# ...

# %%
dfAll.count()
# Out:
# tripduration               228742
# starttime                  228742
# stoptime                   228742
# start station id           228742
# start station name         228742
# start station latitude     228742
# start station longitude    228742
# end station id             228742
# end station name           228742
# end station latitude       228742
# end station longitude      228742
# bikeid                     228742
# usertype                   228742
# birth year                 220587
# gender                     228742
# dtype: int64

# %%
export_csv = dfAll.to_csv(r'C:/Users/So Jung Lee/Data Module/Citi Bike Analytics/export_dataframe.csv', index=None, header=True)

# %%
dfAll['miles'] = (dfAll.tripduration/3660)*7.456

# %%
dfAll.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           499  2017-06-01 00:01:39  2017-06-01 00:09:59              3195
# 1           507  2017-06-01 00:06:39  2017-06-01 00:15:07              3211
# 2           768  2017-06-01 00:44:43  2017-06-01 00:57:31              3195
# 3           101  2017-06-01 01:12:55  2017-06-01 01:14:36              3185
# 4           265  2017-06-01 01:14:00  2017-06-01 01:18:25              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# ...

# %%
dfAll.plot.scatter(x='bikeid',y='tripduration')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
dfAll.plot.scatter(x='birth year',y='tripduration')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import seaborn as sns

# %%
sns.regplot(x=dfAll["birth year"], y=dfAll["tripduration"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
dfAll.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  2.287420e+05     228742.000000           228742.000000
# mean   7.718384e+02       3245.491899               40.722519
# std    8.296757e+03        112.773125                0.007528
# min    6.100000e+01       3183.000000               40.692640
# 25%    2.410000e+02       3187.000000               40.717733
# 50%    3.630000e+02       3203.000000               40.721124
# 75%    6.230000e+02       3269.000000               40.727224
# max    2.061932e+06       3694.000000               40.752559
#
#        start station longitude  end station id  end station latitude  \
# count            228742.000000   228742.000000         228742.000000
# mean                -74.045885     3239.380245             40.697906
# std                   0.010689      130.137690              0.992683
# min                 -74.096937       79.000000              0.000000
# ...

# %%
dfAll['tripduration'].value_counts()
# Out:
# 257       602
# 259       601
# 224       597
# 260       592
# 242       591
# 241       589
# 238       587
# 246       584
# 258       583
# 244       579
# 266       579
# 240       572
# 239       572
# 256       572
# 219       572
# 225       571
# 233       571
# 251       570
# 270       569
# 268       569
# 262       568
# 243       568
# 252       566
# 247       563
# 265       562
# 230       561
# 231       561
# 237       560
# 220       560
# 273       560
#          ...
# 4397        1
# 6444        1
# 4833        1
# 4269        1
# 6316        1
# 24739       1
# 13737       1
# 9643        1
# 4786        1
# 24100       1
# 3043        1
# 4530        1
# 11495       1
# 21736       1
# 332178      1
# 7649        1
# 4274        1
# 5728        1
# 10293       1
# 3683        1
# 3811        1
# 5933        1
# 10027       1
# 38640       1
# 5805        1
# 7852        1
# 9899        1
# 5984        1
# 3630        1
# 6564        1
# ...

# %%
outliers = dfAll[dfAll['tripduration'] > dfAll['tripduration'].mean() + 3 * dfAll['tripduration'].std()]

# %%
outliers.count()
# Out:
# tripduration               374
# starttime                  374
# stoptime                   374
# start station id           374
# start station name         374
# start station latitude     374
# start station longitude    374
# end station id             374
# end station name           374
# end station latitude       374
# end station longitude      374
# bikeid                     374
# usertype                   374
# birth year                 240
# gender                     374
# miles                      374
# dtype: int64
